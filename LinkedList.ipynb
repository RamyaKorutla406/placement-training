# %% [markdown]
# <a href="https://colab.research.google.com/github/RamyaKorutla406/placement-training/blob/main/LinkedList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Node:
  def __init__(self,val):
    self.data=val
    self.next=None
class LinkedList:
  def __init__(self):
    self.head=None
  def append(self,val):
    temp=self.head
    while(temp.next!=None):
      temp=temp.next
    temp.next=Node(val)
  def add(self):
     temp=self.head
     sum,i,count=0,0,0
     while(temp!=None):
        count+=1
        if(i%2==0):
          sum+=temp.data
        temp=temp.next
        i+=1
     print(count)
  def display(self):
    temp=self.head
    while(temp!=None):
      print(temp.data,end="->")
      temp=temp.next
    print(None)

l1=LinkedList()
l1.head=Node(1)
l1.append(1)
l1.append(2)
l1.append(3)
l1.add()
l1.display()
# Out:
# 4
# 1->1->2->3->None

# %%
def add(self):
     temp=self.head
     sum,i=0,0
     while(temp!=None):
        if(i%2==0):
          sum+=temp.data
        temp=temp.next
        i+=1
     print(sum)
l1=LinkedList()
l1.head=Node(1)
l1.append(1)
l1.append(2)
l1.append(3)
l1.add()
l1.display()
# Out:
# 3
# 1->1->2->3->None

# %%
class Node:
  def __init__(self, val):
    self.data = val
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def append(self, val):
    temp = self.head
    while(temp.next != None):
      temp = temp.next
    temp.next = Node(val)

  def add(self):
    temp = self.head
    sum, i, count = 0, 0, 0
    while(temp != None):
      count += 1
      if(i % 2 == 0):
        sum += temp.data
      temp = temp.next
      i += 1
    print(count)

  def first_largest(self):
    if self.head == None:
      return
    temp = self.head
    max_val = temp.data
    while temp != None:
      if temp.data > max_val:
        max_val = temp.data
      temp = temp.next
    print(max_val)

  def display(self):
    temp = self.head
    while(temp != None):
      print(temp.data, end="->")
      temp = temp.next
    print(None)
l1 = LinkedList()
l1.head = Node(10)
l1.append(1)
l1.append(2)
l1.append(2)
l1.add()
l1.first_largest()
l1.display()
# Out:
# 4
# 10
# 10->1->2->2->None

# %%
class Node:
  def __init__(self, val):
    self.data = val
    self.next = None
class LinkedList:
  def __init__(self):
    self.head = None
  def append(self, val):
    temp = self.head
    while(temp.next != None):
      temp = temp.next
    temp.next = Node(val)
  def add(self):
    temp = self.head
    sum, i, count = 0, 0, 0
    while(temp != None):
      count += 1
      if(i % 2 == 0):
        sum += temp.data
      temp = temp.next
      i += 1
    print(count)
  def first_largest(self):
    if self.head == None:
      return
    temp = self.head
    max_val = temp.data
    while temp != None:
      if temp.data > max_val:
        max_val = temp.data
      temp = temp.next
    print(max_val)
  def second_largest(self):
    if self.head == None:
      return None
    if self.head.next == None:
      return None
    temp = self.head
    first = self.head.data
    second = None
    temp = temp.next
    while temp != None:
      if temp.data > first:
        second = first
        first = temp.data
      elif temp.data != first:
        if second == None or temp.data > second:
          second = temp.data
      temp = temp.next
    print(second)

  def display(self):
    temp = self.head
    while(temp != None):
      print(temp.data, end="->")
      temp = temp.next
    print(None)
l1 = LinkedList()
l1.head = Node(10)
l1.append(9)
l1.append(2)
l1.append(3)
l1.add()
l1.first_largest()
l1.second_largest()
l1.display()
# Out:
# 4
# 10
# 9
# 10->9->2->3->None

# %%
class Node:
  def __init__(self, val):
    self.data = val
    self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def append(self, val):
    temp = self.head
    while temp.next != None:
      temp = temp.next
    temp.next = Node(val)
  def find_mid(self):
    low = self.head
    high = self.head
    while high != None and high.next != None:
      low = low.next
      high = high.next.next
    return low.data
  def display(self):
    temp = self.head
    while temp != None:
      print(temp.data, end="->")
      temp = temp.next
    print("None")
l1 = LinkedList()
l1.head = Node(10)
l1.append(20)
l1.append(30)
l1.append(40)
l1.append(50)
mid = l1.find_mid()
print(mid)
l1.display()
# Out:
# 30
# 10->20->30->40->50->None

# %%
class ListNode:
    def __init__(self, data=0, next_node=None):
        self.data = data
        self.next = next_node
def detect_and_count_cycle(head):
    slow = fast = head
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
            count = 1
            current = slow.next
            while current != slow:
                count += 1
                current = current.next
            return count
    return 0
a = ListNode(3)
b = ListNode(2)
c = ListNode(0)
d = ListNode(-4)
a.next, b.next, c.next, d.next = b, c, d, b
cnt = detect_and_count_cycle(a)
if cnt:
    print(cnt)
x = ListNode(1)
x.next = ListNode(2)
x.next.next = ListNode(3)
cnt = detect_and_count_cycle(x)
if cnt:
    print(cnt)
# Out:
# 3
