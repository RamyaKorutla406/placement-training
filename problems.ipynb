# %% [markdown]
# <a href="https://colab.research.google.com/github/RamyaKorutla406/placement-training/blob/main/problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Solution:
    def lemonadeChange(self, bills):
        five, ten = 0, 0

        for bill in bills:
            if bill == 5:
                five += 1
            elif bill == 10:
                if five == 0:
                    return False
                five -= 1
                ten += 1
            else:  # bill == 20
                if ten > 0 and five > 0:
                    ten -= 1
                    five -= 1
                elif five >= 3:
                    five -= 3
                else:
                    return False
        return True

# %%
def lemonadeChange(bills):
    five = ten = 0
    profit = 0
    for bill in bills:
        profit += 5
        if bill == 5:
            five += 1
        elif bill == 10:
            if five == 0:
                return False
            five -= 1
            ten += 1
        else:
            if ten > 0 and five > 0:
                ten -= 1
                five -= 1
            elif five >= 3:
                five -= 3
            else:
                return False
    print(f"Total profit: ${profit}")
    return True
print(lemonadeChange([5, 5, 5, 10, 10, 20]))
# Out:
# Total profit: $30
# True

# %%
from typing import List
class Solution:
    def find132pattern(self, nums: List[int]) -> bool:
        stack = []
        third = float('-inf')
        for num in reversed(nums):
            if num < third:
                return True
            while stack and num > stack[-1]:
                third = stack.pop()
            stack.append(num)
        return False

# %%
s="aaabbc"
res=[]
c=1
for i in range(len(s)):
    if i>0 and s[i]==s[i-1]:
        c+=1
    else:
        c=1
    if c<=2:
        res.append(s[i])
print("".join(res))
# Out:
# aabbc

# %%
a = "aaaabbbc"
count = {}
for ch in a:
    if ch in count:
        count[ch] += 1
    else:
        count[ch] = 1
for key in count:
    print(f"{key} = {count[key]}")
# Out:
# a = 4
# b = 3
# c = 1

# %%
s="aaabbcc"
res=[]
c=1
for i in range(len(s)):
    if i>0 and s[i]==s[i-1]:
        c+=1
    else:
        c=1
    if c>2:
        res.append(s[i])
print("".join(res))
# Out:
# a
